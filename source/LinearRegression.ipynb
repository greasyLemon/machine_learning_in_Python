# %% [markdown]
# <a href="https://colab.research.google.com/github/greasyLemon/machine_learning_in_Python/blob/main/source/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([[147, 150, 153, 158, 163, 165, 168, 170, 173, 175, 178, 180, 183]]).T
y = np.array([[49, 50, 51,  54, 58, 59, 60, 62, 63, 64, 66, 67, 68]]).T

# %%
plt.plot(X, y, 'ro')
plt.axis([140, 190, 45, 75])
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
# Weight = w_1*Height + w_0
one = np.ones((X.shape[0], 1))
Xbar = np.concatenate((one, X), axis = 1)

# %%
A = np.dot(Xbar.T, Xbar)
b = np.dot(Xbar.T, y)
w = np.dot(np.linalg.pinv(A), b)
print('w= ', w)
# Out:
# w=  [[-33.73541021]
#  [  0.55920496]]

# %%
w_0 = w[0][0]
w_1 = w[1][0]
x0 = np.linspace(145, 185, 2)
y0 = w_0 + w_1*x0

# %%
plt.plot(X.T, y.T, 'ro')
plt.plot(x0, y0)
plt.axis([145, 185, 45, 75])
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
y0 = w_0 + w_1*168
print(y0)
# Out:
# 60.21102340005757

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression(fit_intercept=False)
regr.fit(Xbar, y)

print(regr.coef_)
print(w.T)
# Out:
# [[-33.73541021   0.55920496]]
# [[-33.73541021   0.55920496]]
